# %%
from rasterstats import zonal_stats
import rasterstats

# %%
cmap = {} 
vector = r"N:\GISData\Active\Germaine_PygmyRabbits\Analysis_WellEffects\DerivedData\Well_Sage_Correlation_Buffer30m.shp"
raster = r"N:\GISData\Active\Germaine_PygmyRabbits\Analysis_WellEffects\SourceData\Public_ver_usgs_wyo_sagebrush_jan2012\usgs_wy_sage_v1.img"
stats = zonal_stats(vector, raster, all_touched=True)
               
stats
# Out:
# [{'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 3, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 3, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 3, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
#  {'count': 4, 'max': 0.0, 'mean': 0.0, 'min': 0.0},
# ...
